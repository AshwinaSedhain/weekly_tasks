# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/ashwini/Documents/DataPreprocessing/datas/morley.csv")

# %%
df.head()
# Out:
#    rownames  Expt  Run  Speed
# 0         1     1    1    850
# 1         2     1    2    740
# 2         3     1    3    900
# 3         4     1    4   1070
# 4         5     1    5    930

# %%
#selecting the feature
df[['Speed', 'Expt']]
# Out:
#     Speed  Expt
# 0     850     1
# 1     740     1
# 2     900     1
# 3    1070     1
# 4     930     1
# ..    ...   ...
# 95    940     5
# 96    950     5
# 97    800     5
# 98    810     5
# 99    870     5
#
# [100 rows x 2 columns]

# %%
#Appying k-means custering 
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# %%
sns.scatterplot(
    data=df,
    x='Speed',
    y='Expt',
    hue='Cluster'
)

plt.title("Clustering on Real Dataset")
plt.show()
